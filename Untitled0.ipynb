# %% [markdown]
# <a href="https://colab.research.google.com/github/Robyalfadhli/Pemerograman-dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# soal no 1
#
# Jelaskan defines struktur algoritma perulangan menurut pemahaman Anda dan berikan
# contohnya dalam kehidupa sehari-hari kita?
#
# Struktur algoritma perulangan (looping) adalah bagian dari algoritma yang digunakan untuk mengulang satu atau beberapa instruksi secara berulang hingga suatu kondisi tertentu terpenuhi.
# **contohnya**

# %%
print("--- Soal 2 ---")
# Program menampilkan nama sebanyak 200 kali
for i in range(200):
    print("Nama Saya: Roby")
# Out:
# --- Soal 2 ---
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# Nama Saya: Roby
# ...
